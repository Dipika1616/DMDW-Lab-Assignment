# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipika1616/DMDW-Lab-Assignment/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 4

# %%
lst1 = [] 
lst2 = [] 
 
lst1 = [int(item) for item in input("Enter the  marks of student : ").split()]
 
lst2 = [item for item in input("Enter the names of the sttudent : ").split()]
import numpy as np
import matplotlib.pyplot as plt
# creating the dataset
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(lst2, lst1, color ='black',
        width = 0.4)
plt.xlabel("Name of Student")
plt.ylabel("Mark Secured")
plt.title("Students Result")
plt.show()
# Out:
# Enter the  marks of student : 2 34 59 78 100
# Enter the names of the sttudent : dips bhav shyam pari ram

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("Iris.csv")
print (data.head(10))
plt.figure(figsize = (10, 7))
x = data["SepalLengthCm"]
plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length ")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
# Text(0, 0.5, 'Count')

# %%
new_data = data[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]
print(new_data.head())
plt.figure(figsize = (10, 7))
new_data.boxplot()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
import matplotlib.pyplot as plt
data = data.head(10)

x = data['PetalLengthCm']
y = data['SepalLengthCm']

plt.plot(x, y)
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = ['Group A','Group B','Group C','Group D']
pre = np.array([19, 6, 11, 9])
post = np.array([15, 11, 9, 8])
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, pre, 0.4, label = 'pre')
plt.bar(X_axis + 0.2, post, 0.4, label = 'post')
  
plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %%
import numpy as np
np.linspace(1, 100 , num = 20)
# Out:
# array([  1.        ,   6.21052632,  11.42105263,  16.63157895,
#         21.84210526,  27.05263158,  32.26315789,  37.47368421,
#         42.68421053,  47.89473684,  53.10526316,  58.31578947,
#         63.52631579,  68.73684211,  73.94736842,  79.15789474,
#         84.36842105,  89.57894737,  94.78947368, 100.        ])

# %%
import math
x1=np.arange(11,31)
x2=np.arange(31,51)
x3=np.arange(51,71)
y1=np.sin(x1)
y2=np.cos(x2)
y3=np.tan(x3)
plt.plot(y1,x1,label='x1')
plt.plot(y2,x2,label='x2')
plt.plot(y3,x3,label='x3')
plt.legend()
plt.show()

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
y1=[8,6,7,5,1]
plt.plot(x,y)
plt.scatter(x,y)
plt.plot(y,y1,label="Y and y1 axis")
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend('xyy1')
plt.show()
